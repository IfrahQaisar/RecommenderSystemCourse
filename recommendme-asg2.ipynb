# %%
import pandas as pd

movies = pd.read_csv('../input/movies/movies.csv')  # Assuming you're using the MovieLens dataset
links = pd.read_csv('../input/movies/links.csv')  # Optional, for connecting to external sources like IMDb
tags = pd.read_csv('../input/movies/tags.csv')    # Tags for textual descriptions (Optional)
ratings = pd.read_csv('../input/movies/ratings.csv')  # User ratings data

# Display movie data
print(movies.head())
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Since I couldn't find the file containing description of movies, I am creating a textual description column by combining `title`, `genres`, and `tags`
movies['description'] = movies['title'] + ' ' + movies['genres']

# If `tags` exist, join them to `description`
if 'tags' in locals():
    tags_grouped = tags.groupby('movieId')['tag'].apply(lambda x: ' '.join(x)).reset_index()
    movies = movies.merge(tags_grouped, on='movieId', how='left')
    movies['description'] = movies['description'] + ' ' + movies['tag']

# Fill missing values in description
movies['description'].fillna('', inplace=True)

# Display the combined dataset
print(movies[['movieId', 'description']].head())
# Out:
#    movieId                                        description
# 0        1  Toy Story (1995) Adventure|Animation|Children|...
# 1        2  Jumanji (1995) Adventure|Children|Fantasy fant...
# 2        3   Grumpier Old Men (1995) Comedy|Romance moldy old
# 3        4
# 4        5  Father of the Bride Part II (1995) Comedy preg...

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')  # Optional: Required for some WordNet functionalities
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import os

folder_path = './nltk_data' 
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    print(f"Folder '{folder_path}' created successfully.")
else:
    print(f"Folder '{folder_path}' already exists.")
# Out:
# Folder './nltk_data' created successfully.

# %%
import nltk
nltk.data.path.append('./nltk_data')  # Add the path to NLTK data location
nltk.download('stopwords', download_dir='./nltk_data')
nltk.download('wordnet', download_dir='./nltk_data')
nltk.download('omw-1.4', download_dir='./nltk_data')
# Out:
# [nltk_data] Downloading package stopwords to ./nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to ./nltk_data...
# [nltk_data] Downloading package omw-1.4 to ./nltk_data...
# True

# %%
import nltk
nltk.download('stopwords', download_dir='./nltk_data')
nltk.download('wordnet', download_dir='./nltk_data')
nltk.download('omw-1.4', download_dir='./nltk_data')
# Out:
# [nltk_data] Downloading package stopwords to ./nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to ./nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to ./nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import os


os.listdir('.')

for root, dirs, files in os.walk("."):
    print(f"Directory: {root}")
    for file in files:
        print(f"  - {file}")
# Out:
# Directory: .
# Directory: ./.virtual_documents
# Directory: ./nltk_data
# Directory: ./nltk_data/corpora
#   - wordnet.zip
#   - omw-1.4.zip
#   - stopwords.zip
# Directory: ./nltk_data/corpora/stopwords
#   - catalan
#   - danish
#   - indonesian
#   - dutch
#   - bengali
#   - hinglish
#   - tajik
#   - italian
#   - slovene
#   - finnish
#   - french
#   - english
#   - portuguese
#   - swedish
#   - hungarian
#   - basque
#   - arabic
#   - turkish
#   - romanian
#   - kazakh
#   - chinese
#   - norwegian
#   - README
#   - russian
#   - nepali
#   - hebrew
#   - german
#   - greek
#   - azerbaijani
#   - spanish

# %%
import zipfile
import os


nltk_data_dir = './nltk_data/corpora/'

zip_files = ['wordnet.zip', 'omw-1.4.zip', 'stopwords.zip']

for zip_file in zip_files:
    with zipfile.ZipFile(os.path.join(nltk_data_dir, zip_file), 'r') as zip_ref:
        zip_ref.extractall(os.path.join(nltk_data_dir))

print("Unzipped all the files successfully.")
# Out:
# Unzipped all the files successfully.

# %%
import nltk

# Check if WordNet is available
print("WordNet available:", nltk.data.find("corpora/wordnet"))

# Check if stopwords are available
print("Stopwords available:", nltk.data.find("corpora/stopwords"))
# Out:
# WordNet available: /kaggle/working/nltk_data/corpora/wordnet
# Stopwords available: /usr/share/nltk_data/corpora/stopwords

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Load NLTK resources
nltk.download('stopwords', download_dir='./nltk_data')
nltk.download('wordnet', download_dir='./nltk_data')
nltk.download('omw-1.4', download_dir='./nltk_data')

# Preprocessing function
def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    # Tokenize and remove stopwords, then lemmatize
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Apply preprocessing to the 'description' column
if "description" in movies.columns:
    movies['cleaned_description'] = movies['description'].apply(preprocess_text)
    print(movies[['description', 'cleaned_description']].head())
else:
    print("Description column not found in the dataframe.")
# Out:
# [nltk_data] Downloading package stopwords to ./nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to ./nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to ./nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                          description  \
# 0  Toy Story (1995) Adventure|Animation|Children|...
# 1  Jumanji (1995) Adventure|Children|Fantasy fant...
# 2   Grumpier Old Men (1995) Comedy|Romance moldy old
# 3
# 4  Father of the Bride Part II (1995) Comedy preg...
#
#                                  cleaned_description
# 0  Toy Story (1995) Adventure|Animation|Children|...
# 1  Jumanji (1995) Adventure|Children|Fantasy fant...
# 2   Grumpier Old Men (1995) Comedy|Romance moldy old
# 3
# 4  Father Bride Part II (1995) Comedy pregnancy r...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TF-IDF Vectorizer
tfidf = TfidfVectorizer(max_features=5000)  # Use top 5000 features

# Transform descriptions into TF-IDF feature matrix
X = tfidf.fit_transform(movies['cleaned_description']).toarray()

# Print the feature matrix
print(X.shape)
# Out:
# (9742, 3787)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Assuming 'genre' is the column containing the categories (update based on your dataset)
labels = movies['genres']

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.2, random_state=42)

# Initialize Logistic Regression Model
model = LogisticRegression(max_iter=500)

# Train the model on the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.14520266803488968
# Classification Report:
#                                                                  precision    recall  f1-score   support
#
#                                             (no genres listed)       0.00      0.00      0.00         7
#                                                         Action       0.00      0.00      0.00        10
#                                               Action|Adventure       0.00      0.00      0.00         5
#                                     Action|Adventure|Animation       0.00      0.00      0.00         1
#                            Action|Adventure|Animation|Children       0.00      0.00      0.00         1
#                     Action|Adventure|Animation|Children|Comedy       0.00      0.00      0.00         3
#              Action|Adventure|Animation|Children|Comedy|Sci-Fi       0.00      0.00      0.00         1
#             Action|Adventure|Animation|Children|Fantasy|Sci-Fi       0.00      0.00      0.00         2
#                       Action|Adventure|Animation|Comedy|Sci-Fi       0.00      0.00      0.00         1
#                     Action|Adventure|Animation|Comedy|Thriller       0.00      0.00      0.00         1
#                       Action|Adventure|Animation|Drama|Fantasy       0.00      0.00      0.00         2
#                             Action|Adventure|Animation|Fantasy       0.00      0.00      0.00         2
#                        Action|Adventure|Animation|Fantasy|IMAX       0.00      0.00      0.00         1
#                      Action|Adventure|Animation|Fantasy|Sci-Fi       0.00      0.00      0.00         2
#                              Action|Adventure|Animation|Horror       0.00      0.00      0.00         1
#                              Action|Adventure|Animation|Sci-Fi       0.00      0.00      0.00         1
#                               Action|Adventure|Children|Comedy       0.00      0.00      0.00         2
#               Action|Adventure|Children|Crime|Mystery|Thriller       0.00      0.00      0.00         1
#                                        Action|Adventure|Comedy       0.00      0.00      0.00         1
#                                  Action|Adventure|Comedy|Crime       0.00      0.00      0.00         3
#                                Action|Adventure|Comedy|Fantasy       0.00      0.00      0.00         1
#                        Action|Adventure|Comedy|Fantasy|Romance       0.00      0.00      0.00         1
#                                Action|Adventure|Comedy|Romance       0.00      0.00      0.00         1
#                                 Action|Adventure|Comedy|Sci-Fi       0.00      0.00      0.00         1
#                               Action|Adventure|Comedy|Thriller       0.00      0.00      0.00         1
#                                Action|Adventure|Comedy|Western       0.00      0.00      0.00         1
#                  Action|Adventure|Crime|Drama|Romance|Thriller       0.00      0.00      0.00         1
#                                Action|Adventure|Crime|Thriller       0.00      0.00      0.00         1
#                                         Action|Adventure|Drama       0.00      0.00      0.00         5
#                                 Action|Adventure|Drama|Fantasy       0.00      0.00      0.00         2
#                         Action|Adventure|Drama|Fantasy|Romance       0.00      0.00      0.00         1
#         Action|Adventure|Drama|Fantasy|Romance|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                        Action|Adventure|Drama|Fantasy|Thriller       0.00      0.00      0.00         1
#                         Action|Adventure|Drama|Sci-Fi|Thriller       0.00      0.00      0.00         3
#                                Action|Adventure|Drama|Thriller       0.00      0.00      0.00         4
#                                     Action|Adventure|Drama|War       0.00      0.00      0.00         1
#                                 Action|Adventure|Drama|Western       0.00      0.00      0.00         1
#                                       Action|Adventure|Fantasy       0.00      0.00      0.00        12
#                                Action|Adventure|Fantasy|Horror       0.00      0.00      0.00         1
#                       Action|Adventure|Fantasy|Horror|Thriller       0.00      0.00      0.00         1
#                                  Action|Adventure|Fantasy|IMAX       0.00      0.00      0.00         3
#                          Action|Adventure|Fantasy|Romance|IMAX       0.00      0.00      0.00         1
#                                Action|Adventure|Fantasy|Sci-Fi       0.00      0.00      0.00         5
#                           Action|Adventure|Fantasy|Sci-Fi|IMAX       0.00      0.00      0.00         1
#                              Action|Adventure|Fantasy|Thriller       0.00      0.00      0.00         2
#                                 Action|Adventure|Horror|Sci-Fi       0.00      0.00      0.00         1
#                        Action|Adventure|Horror|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                       Action|Adventure|Romance       0.00      0.00      0.00         2
#                              Action|Adventure|Romance|Thriller       0.00      0.00      0.00         1
#                                        Action|Adventure|Sci-Fi       0.25      0.15      0.19        13
#                                   Action|Adventure|Sci-Fi|IMAX       0.00      0.00      0.00         3
#                               Action|Adventure|Sci-Fi|Thriller       0.00      0.00      0.00         7
#                          Action|Adventure|Sci-Fi|Thriller|IMAX       0.00      0.00      0.00         1
#                                      Action|Adventure|Thriller       0.00      0.00      0.00         6
#                                 Action|Adventure|Thriller|IMAX       0.00      0.00      0.00         2
#                                           Action|Adventure|War       0.00      0.00      0.00         2
#                                               Action|Animation       0.00      0.00      0.00         4
#                               Action|Animation|Children|Comedy       0.00      0.00      0.00         2
#                                Action|Animation|Children|Crime       0.00      0.00      0.00         1
#           Action|Animation|Comedy|Crime|Drama|Romance|Thriller       0.00      0.00      0.00         1
#                                 Action|Animation|Comedy|Horror       0.00      0.00      0.00         1
#                         Action|Animation|Comedy|Romance|Sci-Fi       0.00      0.00      0.00         1
#                                         Action|Animation|Crime       0.00      0.00      0.00         1
# Action|Animation|Crime|Drama|Film-Noir|Mystery|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                  Action|Animation|Drama|Sci-Fi       0.00      0.00      0.00         2
#                                        Action|Animation|Sci-Fi       0.00      0.00      0.00         2
#                                                Action|Children       0.00      0.00      0.00         1
#                                         Action|Children|Comedy       0.00      0.00      0.00         2
#                                                  Action|Comedy       0.00      0.00      0.00        18
#                                            Action|Comedy|Crime       0.00      0.00      0.00         9
#                                      Action|Comedy|Crime|Drama       0.00      0.00      0.00         2
#                               Action|Comedy|Crime|Drama|Sci-Fi       0.00      0.00      0.00         1
#                             Action|Comedy|Crime|Drama|Thriller       0.00      0.00      0.00         4
#                                    Action|Comedy|Crime|Romance       0.00      0.00      0.00         1
#                                   Action|Comedy|Crime|Thriller       0.00      0.00      0.00         5
#                                      Action|Comedy|Documentary       0.00      0.00      0.00         1
#                                            Action|Comedy|Drama       0.00      0.00      0.00         2
#                                        Action|Comedy|Drama|War       0.00      0.00      0.00         1
#                                          Action|Comedy|Fantasy       0.00      0.00      0.00         1
#                                   Action|Comedy|Fantasy|Horror       0.00      0.00      0.00         2
#                                    Action|Comedy|Horror|Sci-Fi       0.00      0.00      0.00         1
#                                          Action|Comedy|Musical       0.00      0.00      0.00         2
#                                          Action|Comedy|Romance       0.00      0.00      0.00         2
#                                           Action|Comedy|Sci-Fi       0.00      0.00      0.00         3
#                                   Action|Comedy|Sci-Fi|Western       0.00      0.00      0.00         1
#                                              Action|Comedy|War       0.00      0.00      0.00         1
#                                                   Action|Crime       0.00      0.00      0.00         3
#                                             Action|Crime|Drama       0.00      0.00      0.00         9
#                             Action|Crime|Drama|Horror|Thriller       0.00      0.00      0.00         1
#                            Action|Crime|Drama|Mystery|Thriller       0.00      0.00      0.00         1
#                                    Action|Crime|Drama|Thriller       0.00      0.00      0.00        12
#                                  Action|Crime|Fantasy|Thriller       0.00      0.00      0.00         1
#                                            Action|Crime|Horror       0.00      0.00      0.00         2
#                            Action|Crime|Horror|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                   Action|Crime|Horror|Thriller       0.00      0.00      0.00         1
#                                           Action|Crime|Mystery       0.00      0.00      0.00         1
#                                  Action|Crime|Mystery|Thriller       0.00      0.00      0.00         1
#                                   Action|Crime|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                          Action|Crime|Thriller       0.00      0.00      0.00        14
#                                                   Action|Drama       0.00      0.00      0.00         9
#                                   Action|Drama|Horror|Thriller       0.00      0.00      0.00         2
#                           Action|Drama|Mystery|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                  Action|Drama|Romance|Thriller       0.00      0.00      0.00         1
#                                            Action|Drama|Sci-Fi       0.00      0.00      0.00         1
#                                       Action|Drama|Sci-Fi|IMAX       0.00      0.00      0.00         1
#                                   Action|Drama|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                          Action|Drama|Thriller       0.00      0.00      0.00         8
#                                     Action|Drama|Thriller|IMAX       0.00      0.00      0.00         1
#                                      Action|Drama|Thriller|War       0.00      0.00      0.00         1
#                                               Action|Drama|War       0.00      0.00      0.00         9
#                                          Action|Drama|War|IMAX       0.00      0.00      0.00         1
#                                          Action|Fantasy|Horror       0.00      0.00      0.00         1
#                                 Action|Fantasy|Horror|Thriller       0.00      0.00      0.00         2
#                                          Action|Fantasy|Sci-Fi       0.00      0.00      0.00         1
#                                     Action|Fantasy|Sci-Fi|IMAX       0.00      0.00      0.00         1
#                                 Action|Fantasy|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                        Action|Fantasy|War|IMAX       0.00      0.00      0.00         1
#                                         Action|Fantasy|Western       0.00      0.00      0.00         1
#                                                  Action|Horror       0.00      0.00      0.00         1
#                                           Action|Horror|Sci-Fi       0.00      0.00      0.00         4
#                                  Action|Horror|Sci-Fi|Thriller       0.00      0.00      0.00         5
#                                         Action|Horror|Thriller       0.00      0.00      0.00         5
#                                          Action|Mystery|Sci-Fi       0.00      0.00      0.00         2
#                                        Action|Mystery|Thriller       0.00      0.00      0.00         1
#                                        Action|Romance|Thriller       0.00      0.00      0.00         1
#                                     Action|Romance|War|Western       0.00      0.00      0.00         1
#                                                  Action|Sci-Fi       0.00      0.00      0.00         6
#                                         Action|Sci-Fi|Thriller       0.00      0.00      0.00        17
#                                    Action|Sci-Fi|Thriller|IMAX       0.00      0.00      0.00         2
#                            Action|Sci-Fi|Thriller|Western|IMAX       0.00      0.00      0.00         1
#                                                Action|Thriller       0.00      0.00      0.00        13
#                                            Action|Thriller|War       0.00      0.00      0.00         1
#                                        Action|Thriller|Western       0.00      0.00      0.00         1
#                                                     Action|War       0.00      0.00      0.00         3
#                                                 Action|Western       0.00      0.00      0.00         2
#                                                      Adventure       0.00      0.00      0.00         1
#                                            Adventure|Animation       0.00      0.00      0.00         1
#                                   Adventure|Animation|Children       0.00      0.00      0.00         4
#                            Adventure|Animation|Children|Comedy       0.00      0.00      0.00         6
#              Adventure|Animation|Children|Comedy|Drama|Romance       0.00      0.00      0.00         1
#                    Adventure|Animation|Children|Comedy|Fantasy       0.00      0.00      0.00         3
#            Adventure|Animation|Children|Comedy|Fantasy|Romance       0.00      0.00      0.00         1
#             Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi       0.00      0.00      0.00         1
#        Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi|IMAX       0.00      0.00      0.00         1
#                       Adventure|Animation|Children|Comedy|IMAX       0.00      0.00      0.00         1
#                    Adventure|Animation|Children|Comedy|Musical       0.00      0.00      0.00         1
#                     Adventure|Animation|Children|Comedy|Sci-Fi       0.00      0.00      0.00         1
#                             Adventure|Animation|Children|Drama       0.00      0.00      0.00         1
#                   Adventure|Animation|Children|Fantasy|Musical       0.00      0.00      0.00         2
#                    Adventure|Animation|Children|Fantasy|Sci-Fi       0.00      0.00      0.00         1
#                           Adventure|Animation|Children|Musical       0.00      0.00      0.00         2
#                   Adventure|Animation|Children|Musical|Romance       0.00      0.00      0.00         1
#                   Adventure|Animation|Children|Musical|Western       0.00      0.00      0.00         1
#                            Adventure|Animation|Children|Sci-Fi       0.00      0.00      0.00         2
#                                     Adventure|Animation|Comedy       0.00      0.00      0.00         2
#                              Adventure|Animation|Comedy|Sci-Fi       0.00      0.00      0.00         1
#                                      Adventure|Animation|Drama       0.00      0.00      0.00         1
#                                    Adventure|Animation|Fantasy       0.00      0.00      0.00         1
#                                     Adventure|Animation|Sci-Fi       0.00      0.00      0.00         1
#                                             Adventure|Children       0.00      0.00      0.00         2
#                                      Adventure|Children|Comedy       0.00      0.00      0.00         6
#                                Adventure|Children|Comedy|Drama       0.00      0.00      0.00         2
#                      Adventure|Children|Comedy|Fantasy|Musical       0.00      0.00      0.00         1
#                      Adventure|Children|Comedy|Fantasy|Romance       0.00      0.00      0.00         1
#                              Adventure|Children|Comedy|Musical       0.00      0.00      0.00         1
#                              Adventure|Children|Comedy|Mystery       0.00      0.00      0.00         1
#                                       Adventure|Children|Drama       0.00      0.00      0.00         1
#                          Adventure|Children|Drama|Fantasy|IMAX       0.00      0.00      0.00         1
#                                     Adventure|Children|Fantasy       0.00      0.00      0.00         5
#                                     Adventure|Children|Musical       0.00      0.00      0.00         1
#                                      Adventure|Children|Sci-Fi       0.00      0.00      0.00         2
#                                               Adventure|Comedy       0.00      0.00      0.00         5
#                           Adventure|Comedy|Crime|Drama|Romance       0.00      0.00      0.00         1
#                                 Adventure|Comedy|Crime|Mystery       0.00      0.00      0.00         1
#                                 Adventure|Comedy|Crime|Romance       0.00      0.00      0.00         1
#                                   Adventure|Comedy|Documentary       0.00      0.00      0.00         1
#                                         Adventure|Comedy|Drama       0.00      0.00      0.00         3
#                                 Adventure|Comedy|Drama|Fantasy       0.00      0.00      0.00         1
#         Adventure|Comedy|Drama|Fantasy|Mystery|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                       Adventure|Comedy|Fantasy       0.00      0.00      0.00         2
#                                Adventure|Comedy|Fantasy|Sci-Fi       0.00      0.00      0.00         1
#                                       Adventure|Comedy|Musical       0.00      0.00      0.00         1
#                                Adventure|Comedy|Musical|Sci-Fi       0.00      0.00      0.00         1
#                                       Adventure|Comedy|Romance       0.00      0.00      0.00         1
#                                   Adventure|Comedy|Romance|War       0.00      0.00      0.00         2
#                                        Adventure|Comedy|Sci-Fi       0.00      0.00      0.00         2
#                                      Adventure|Comedy|Thriller       0.00      0.00      0.00         1
#                                          Adventure|Crime|Drama       0.00      0.00      0.00         2
#                                       Adventure|Crime|Thriller       0.00      0.00      0.00         1
#                                          Adventure|Documentary       0.00      0.00      0.00         1
#                                                Adventure|Drama       0.00      0.00      0.00         8
#                           Adventure|Drama|Fantasy|Romance|IMAX       0.00      0.00      0.00         1
#                                        Adventure|Drama|Romance       0.00      0.00      0.00         4
#                                         Adventure|Drama|Sci-Fi       0.00      0.00      0.00         1
#                                       Adventure|Drama|Thriller       0.00      0.00      0.00         2
#                                  Adventure|Drama|Thriller|IMAX       0.00      0.00      0.00         1
#                                            Adventure|Drama|War       0.00      0.00      0.00         1
#                                    Adventure|Drama|War|Western       0.00      0.00      0.00         1
#                                        Adventure|Drama|Western       0.00      0.00      0.00         1
#                                              Adventure|Fantasy       0.00      0.00      0.00         2
#                                         Adventure|Fantasy|IMAX       0.00      0.00      0.00         2
#                                       Adventure|Fantasy|Sci-Fi       0.00      0.00      0.00         2
#                                              Adventure|Romance       0.00      0.00      0.00         2
#                                       Adventure|Romance|Sci-Fi       0.00      0.00      0.00         1
#                                     Adventure|Romance|Thriller       0.00      0.00      0.00         1
#                                               Adventure|Sci-Fi       0.00      0.00      0.00         6
#                                             Adventure|Thriller       0.00      0.00      0.00         1
#                                          Adventure|War|Western       0.00      0.00      0.00         1
#                                              Adventure|Western       0.00      0.00      0.00         1
#                                                      Animation       0.00      0.00      0.00         4
#                                             Animation|Children       0.00      0.00      0.00         7
#                                      Animation|Children|Comedy       0.00      0.00      0.00         4
#                                Animation|Children|Comedy|Drama       0.00      0.00      0.00         1
#                              Animation|Children|Comedy|Fantasy       0.00      0.00      0.00         3
#                              Animation|Children|Comedy|Musical       0.00      0.00      0.00         2
#                              Animation|Children|Comedy|Romance       0.00      0.00      0.00         1
#                       Animation|Children|Drama|Fantasy|Musical       0.00      0.00      0.00         1
#                       Animation|Children|Drama|Musical|Romance       0.00      0.00      0.00         1
#                                     Animation|Children|Fantasy       0.00      0.00      0.00         1
#                                Animation|Children|Fantasy|IMAX       0.00      0.00      0.00         1
#                             Animation|Children|Fantasy|Musical       0.00      0.00      0.00         4
#                     Animation|Children|Fantasy|Musical|Romance       0.00      0.00      0.00         1
#                                     Animation|Children|Musical       0.00      0.00      0.00         1
#                                               Animation|Comedy       0.00      0.00      0.00         5
#                                         Animation|Comedy|Drama       0.00      0.00      0.00         1
#                                       Animation|Comedy|Fantasy       0.00      0.00      0.00         3
#                               Animation|Comedy|Fantasy|Musical       0.00      0.00      0.00         1
#                                       Animation|Comedy|Musical       0.00      0.00      0.00         2
#                                        Animation|Comedy|Sci-Fi       0.00      0.00      0.00         3
#                                          Animation|Documentary       0.00      0.00      0.00         1
#                                                Animation|Drama       0.00      0.00      0.00         2
#                        Animation|Drama|Mystery|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                        Animation|Drama|Romance       0.00      0.00      0.00         2
#                                 Animation|Drama|Romance|Sci-Fi       0.00      0.00      0.00         1
#                                         Animation|Drama|Sci-Fi       0.00      0.00      0.00         1
#                                              Animation|Fantasy       0.00      0.00      0.00         1
#                                      Animation|Fantasy|Mystery       0.00      0.00      0.00         1
#                                       Animation|Horror|Mystery       0.00      0.00      0.00         1
#                              Animation|Horror|Mystery|Thriller       0.00      0.00      0.00         1
#                                              Animation|Musical       0.00      0.00      0.00         1
#                                              Animation|Romance       0.00      0.00      0.00         1
#                                               Animation|Sci-Fi       0.00      0.00      0.00         3
#                                                Children|Comedy       0.00      0.00      0.00        22
#                            Children|Comedy|Crime|Drama|Fantasy       0.00      0.00      0.00         1
#                                          Children|Comedy|Drama       0.00      0.00      0.00         2
#                                        Children|Comedy|Fantasy       0.00      0.00      0.00         3
#                                 Children|Comedy|Fantasy|Horror       0.00      0.00      0.00         1
#                                        Children|Comedy|Romance       0.00      0.00      0.00         2
#                                        Children|Comedy|Western       0.00      0.00      0.00         1
#                                           Children|Documentary       0.00      0.00      0.00         1
#                                         Children|Drama|Fantasy       0.00      0.00      0.00         1
#                                 Children|Drama|Fantasy|Romance       0.00      0.00      0.00         1
#                                         Children|Drama|Romance       0.00      0.00      0.00         1
#                                             Children|Drama|War       0.00      0.00      0.00         1
#                                                         Comedy       0.10      1.00      0.19       180
#                                                   Comedy|Crime       0.00      0.00      0.00        27
#                                             Comedy|Crime|Drama       0.00      0.00      0.00         8
#                                     Comedy|Crime|Drama|Musical       0.00      0.00      0.00         1
#                             Comedy|Crime|Drama|Mystery|Romance       0.00      0.00      0.00         1
#                            Comedy|Crime|Drama|Mystery|Thriller       0.00      0.00      0.00         1
#                            Comedy|Crime|Drama|Romance|Thriller       0.00      0.00      0.00         1
#                                    Comedy|Crime|Drama|Thriller       0.00      0.00      0.00         2
#                                            Comedy|Crime|Horror       0.00      0.00      0.00         1
#                                   Comedy|Crime|Mystery|Romance       0.00      0.00      0.00         1
#                                  Comedy|Crime|Mystery|Thriller       0.00      0.00      0.00         1
#                                           Comedy|Crime|Romance       0.00      0.00      0.00         4
#                                  Comedy|Crime|Romance|Thriller       0.00      0.00      0.00         1
#                                          Comedy|Crime|Thriller       0.00      0.00      0.00         1
#                                             Comedy|Documentary       0.00      0.00      0.00         3
#                               Comedy|Documentary|Drama|Romance       0.00      0.00      0.00         1
#                                                   Comedy|Drama       0.56      0.06      0.10        89
#                                           Comedy|Drama|Fantasy       0.00      0.00      0.00         2
#                                   Comedy|Drama|Fantasy|Romance       0.00      0.00      0.00         2
#                                    Comedy|Drama|Fantasy|Sci-Fi       0.00      0.00      0.00         1
#                                            Comedy|Drama|Horror       0.00      0.00      0.00         2
#                                           Comedy|Drama|Musical       0.00      0.00      0.00         5
#                                   Comedy|Drama|Musical|Romance       0.00      0.00      0.00         1
#                                           Comedy|Drama|Mystery       0.00      0.00      0.00         1
#                                           Comedy|Drama|Romance       0.62      0.24      0.34        42
#                                       Comedy|Drama|Romance|War       0.00      0.00      0.00         1
#                                            Comedy|Drama|Sci-Fi       0.00      0.00      0.00         1
#                                               Comedy|Drama|War       0.00      0.00      0.00         4
#                                                 Comedy|Fantasy       0.00      0.00      0.00         4
#                                          Comedy|Fantasy|Horror       0.00      0.00      0.00         5
#                                   Comedy|Fantasy|Horror|Sci-Fi       0.00      0.00      0.00         1
#                                         Comedy|Fantasy|Romance       0.00      0.00      0.00         2
#                                                  Comedy|Horror       0.00      0.00      0.00        15
#                                             Comedy|Horror|IMAX       0.00      0.00      0.00         1
#                                          Comedy|Horror|Musical       0.00      0.00      0.00         1
#                                 Comedy|Horror|Mystery|Thriller       0.00      0.00      0.00         1
#                                          Comedy|Horror|Romance       0.00      0.00      0.00         1
#                                           Comedy|Horror|Sci-Fi       0.00      0.00      0.00         2
#                                  Comedy|Horror|Sci-Fi|Thriller       0.00      0.00      0.00         2
#                                         Comedy|Horror|Thriller       0.00      0.00      0.00         6
#                                                 Comedy|Musical       0.00      0.00      0.00         9
#                                         Comedy|Musical|Romance       0.00      0.00      0.00         3
#                                  Comedy|Musical|Sci-Fi|Western       0.00      0.00      0.00         1
#                                         Comedy|Musical|Western       0.00      0.00      0.00         1
#                                                 Comedy|Mystery       0.00      0.00      0.00         2
#                                                 Comedy|Romance       0.64      0.14      0.23        65
#                                          Comedy|Romance|Sci-Fi       0.00      0.00      0.00         1
#                                 Comedy|Romance|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                        Comedy|Romance|Thriller       0.00      0.00      0.00         1
#                                                  Comedy|Sci-Fi       0.00      0.00      0.00        10
#                                                Comedy|Thriller       0.00      0.00      0.00         6
#                                                     Comedy|War       0.00      0.00      0.00         2
#                                                 Comedy|Western       0.00      0.00      0.00         3
#                                                          Crime       0.00      0.00      0.00         3
#                                                    Crime|Drama       0.20      0.03      0.06        30
#                                            Crime|Drama|Fantasy       0.00      0.00      0.00         1
#                                          Crime|Drama|Film-Noir       0.00      0.00      0.00         3
#                                 Crime|Drama|Film-Noir|Thriller       0.00      0.00      0.00         1
#                                             Crime|Drama|Horror       0.00      0.00      0.00         1
#                                    Crime|Drama|Horror|Thriller       0.00      0.00      0.00         1
#                                            Crime|Drama|Mystery       0.00      0.00      0.00         1
#                           Crime|Drama|Mystery|Romance|Thriller       0.00      0.00      0.00         2
#                                   Crime|Drama|Mystery|Thriller       0.00      0.00      0.00         9
#                                            Crime|Drama|Romance       0.00      0.00      0.00         4
#                                   Crime|Drama|Romance|Thriller       0.00      0.00      0.00         2
#                                        Crime|Drama|Romance|War       0.00      0.00      0.00         1
#                                           Crime|Drama|Thriller       0.00      0.00      0.00        22
#                                                Crime|Film-Noir       0.00      0.00      0.00         2
#                                          Crime|Horror|Thriller       0.00      0.00      0.00         4
#                                                  Crime|Mystery       0.00      0.00      0.00         2
#                                         Crime|Mystery|Thriller       0.00      0.00      0.00         6
#                                         Crime|Romance|Thriller       0.00      0.00      0.00         1
#                                                 Crime|Thriller       0.00      0.00      0.00        12
#                                                    Documentary       0.80      0.19      0.30        64
#                                            Documentary|Fantasy       0.00      0.00      0.00         1
#                                               Documentary|IMAX       0.00      0.00      0.00         3
#                                                Documentary|War       0.00      0.00      0.00         2
#                                                          Drama       0.40      0.23      0.29       218
#                                                  Drama|Fantasy       0.00      0.00      0.00         4
#                                           Drama|Fantasy|Horror       0.00      0.00      0.00         3
#                          Drama|Fantasy|Horror|Mystery|Thriller       0.00      0.00      0.00         1
#                                   Drama|Fantasy|Horror|Romance       0.00      0.00      0.00         1
#                          Drama|Fantasy|Horror|Romance|Thriller       0.00      0.00      0.00         1
#                                          Drama|Fantasy|Romance       0.00      0.00      0.00         1
#                                   Drama|Fantasy|Romance|Sci-Fi       0.00      0.00      0.00         1
#                                           Drama|Fantasy|Sci-Fi       0.00      0.00      0.00         1
#                                         Drama|Fantasy|Thriller       0.00      0.00      0.00         1
#                                                Drama|Film-Noir       0.00      0.00      0.00         1
#                                Drama|Film-Noir|Mystery|Romance       0.00      0.00      0.00         1
#                               Drama|Film-Noir|Mystery|Thriller       0.00      0.00      0.00         1
#                                       Drama|Film-Noir|Thriller       0.00      0.00      0.00         1
#                                                   Drama|Horror       0.00      0.00      0.00         9
#                                           Drama|Horror|Mystery       0.00      0.00      0.00         2
#                          Drama|Horror|Mystery|Romance|Thriller       0.00      0.00      0.00         1
#                                  Drama|Horror|Mystery|Thriller       0.00      0.00      0.00         2
#                                            Drama|Horror|Sci-Fi       0.00      0.00      0.00         3
#                                   Drama|Horror|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                          Drama|Horror|Thriller       0.00      0.00      0.00         9
#                                                  Drama|Musical       0.00      0.00      0.00        13
#                                          Drama|Musical|Mystery       0.00      0.00      0.00         1
#                                          Drama|Musical|Romance       0.00      0.00      0.00         5
#                                                  Drama|Mystery       0.00      0.00      0.00         9
#                                          Drama|Mystery|Romance       0.00      0.00      0.00         3
#                          Drama|Mystery|Romance|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                 Drama|Mystery|Romance|Thriller       0.00      0.00      0.00         2
#                                           Drama|Mystery|Sci-Fi       0.00      0.00      0.00         2
#                                  Drama|Mystery|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                         Drama|Mystery|Thriller       1.00      0.12      0.22         8
#                                                  Drama|Romance       0.39      0.13      0.19        70
#                                           Drama|Romance|Sci-Fi       0.00      0.00      0.00         2
#                                         Drama|Romance|Thriller       0.00      0.00      0.00         3
#                                              Drama|Romance|War       0.00      0.00      0.00         1
#                                          Drama|Romance|Western       0.00      0.00      0.00         2
#                                                   Drama|Sci-Fi       0.00      0.00      0.00         5
#                                              Drama|Sci-Fi|IMAX       0.00      0.00      0.00         1
#                                          Drama|Sci-Fi|Thriller       0.00      0.00      0.00         5
#                                     Drama|Sci-Fi|Thriller|IMAX       0.00      0.00      0.00         1
#                                                 Drama|Thriller       0.00      0.00      0.00        35
#                                             Drama|Thriller|War       0.00      0.00      0.00         1
#                                                      Drama|War       0.50      0.03      0.06        33
#                                              Drama|War|Western       0.00      0.00      0.00         1
#                                                  Drama|Western       0.00      0.00      0.00         5
#                                                        Fantasy       0.00      0.00      0.00         2
#                                                 Fantasy|Horror       0.00      0.00      0.00         1
#                                  Fantasy|Horror|Sci-Fi|Western       0.00      0.00      0.00         1
#                                        Fantasy|Horror|Thriller       0.00      0.00      0.00         2
#                                       Fantasy|Mystery|Thriller       0.00      0.00      0.00         1
#                                        Fantasy|Mystery|Western       0.00      0.00      0.00         1
#                                  Fantasy|Romance|Thriller|IMAX       0.00      0.00      0.00         1
#                                     Film-Noir|Romance|Thriller       0.00      0.00      0.00         1
#                                             Film-Noir|Thriller       0.00      0.00      0.00         1
#                                                         Horror       1.00      0.03      0.05        38
#                                                    Horror|IMAX       0.00      0.00      0.00         2
#                                                 Horror|Mystery       0.00      0.00      0.00         2
#                                 Horror|Mystery|Sci-Fi|Thriller       0.00      0.00      0.00         3
#                                        Horror|Mystery|Thriller       0.00      0.00      0.00         4
#                                                 Horror|Romance       0.00      0.00      0.00         1
#                                          Horror|Romance|Sci-Fi       0.00      0.00      0.00         1
#                                        Horror|Romance|Thriller       0.00      0.00      0.00         1
#                                                  Horror|Sci-Fi       0.00      0.00      0.00         7
#                                         Horror|Sci-Fi|Thriller       0.00      0.00      0.00         7
#                                                Horror|Thriller       0.50      0.03      0.06        31
#                                                        Musical       0.00      0.00      0.00         5
#                                                Musical|Romance       0.00      0.00      0.00         1
#                                       Mystery|Romance|Thriller       0.00      0.00      0.00         1
#                                                 Mystery|Sci-Fi       0.00      0.00      0.00         1
#                                        Mystery|Sci-Fi|Thriller       0.00      0.00      0.00         2
#                                               Mystery|Thriller       0.00      0.00      0.00         7
#                                                        Romance       0.00      0.00      0.00         4
#                                        Romance|Sci-Fi|Thriller       0.00      0.00      0.00         1
#                                               Romance|Thriller       0.00      0.00      0.00         3
#                                                    Romance|War       0.00      0.00      0.00         1
#                                                Romance|Western       0.00      0.00      0.00         1
#                                                         Sci-Fi       0.00      0.00      0.00         5
#                                                Sci-Fi|Thriller       0.00      0.00      0.00         4
#                                                       Thriller       0.00      0.00      0.00        14
#                                                            War       0.00      0.00      0.00         1
#                                                        Western       0.00      0.00      0.00         3
#
#                                                       accuracy                           0.15      1949
#                                                      macro avg       0.02      0.01      0.01      1949
#                                                   weighted avg       0.20      0.15      0.09      1949
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def recommend_category(description):
   
    cleaned_description = preprocess_text(description)

   
    vectorized_description = tfidf.transform([cleaned_description]).toarray()

    # Predict the category using the trained model
    predicted_category = model.predict(vectorized_description)
    
    return predicted_category[0]

# Example
new_movie_description = "A young programmer is hired to protect a company from hackers."
category = recommend_category(new_movie_description)
print(f"Recommended Category: {category}")
# Out:
# Recommended Category: Drama

# %%
def recommend_category_from_dataset():
 
    movies['cleaned_description'] = movies['description'].apply(preprocess_text)
    vectorized_descriptions = tfidf.transform(movies['cleaned_description']).toarray()


    predicted_categories = model.predict(vectorized_descriptions)
    
 
    movies['predicted_category'] = predicted_categories
    
    return movies[['movieId', 'title', 'predicted_category']]


predicted_movies = recommend_category_from_dataset()


print(predicted_movies.head())
# Out:
#    movieId                               title predicted_category
# 0        1                    Toy Story (1995)             Comedy
# 1        2                      Jumanji (1995)              Drama
# 2        3             Grumpier Old Men (1995)     Comedy|Romance
# 3        4            Waiting to Exhale (1995)             Comedy
# 4        5  Father of the Bride Part II (1995)             Comedy
